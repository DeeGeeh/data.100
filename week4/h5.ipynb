# %%
import pandas as pd
import json

# %%
def gdpPerCapita(filename):
    df = pd.read_json(filename, convert_axes=True)
    modified_df = df.T
    return modified_df

# %%
gdpPerCapita('europe.json')
# Out:
#                  Albania       Andorra       Armenia       Austria  \
# gdp         2.354718e+10  3.785067e+09  2.408575e+10  5.116852e+11
# population  2.745972e+06  8.085600e+04  2.990900e+06  9.131761e+06
#
#                  Belarus       Belgium  Bosnia and Herzegovina      Bulgaria  \
# gdp         7.185738e+10  6.447828e+11            2.751478e+10  1.024077e+11
# population  9.178298e+06  1.178742e+07            3.185073e+06  6.446596e+06
#
#                  Croatia        Cyprus  ...       Romania  Russian Federation  \
# gdp         8.439380e+10  3.388693e+10  ...  3.507759e+11        2.021421e+12
# population  3.859686e+06  1.344976e+06  ...  1.905948e+07        1.438261e+08
#
#                   Serbia  Slovak Republic      Slovenia         Spain  \
# gdp         8.134266e+10     1.329083e+11  6.914847e+10  1.620091e+12
# population  6.623183e+06     5.426740e+06  2.120461e+06  4.834791e+07
#
#                   Sweden   Switzerland       Ukraine  United Kingdom
# ...
